# %% [markdown]
# <a href="https://colab.research.google.com/github/raracan07/first/blob/main/Klasifikasi_Mata_Uang_Rupiah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
base_dir = '/content/drive/My Drive/model rupiah/'
# !ls "/content/drive/My Drive/model rupiah/"
# Out:
# bahan  latih  validasi

# %%
#menentukan direktori
bahan_dir = os.path.join(base_dir, 'bahan')
train_dir = os.path.join(base_dir, 'latih')
validation_dir = os.path.join(base_dir, 'validasi')

# %%
#menentukan direktori isi bahan
seratus_dir =os.path.join(bahan_dir, 'seratus/')
tujuhpuluhlima_dir =os.path.join(bahan_dir, 'tujuhpuluhlima/')
limapuluh_dir =os.path.join(bahan_dir, 'limapuluh/')
duapuluh_dir =os.path.join(bahan_dir, 'duapuluh/')
sepuluh_dir =os.path.join(bahan_dir, 'sepuluh/')
limaribu_dir =os.path.join(bahan_dir, 'limaribu/')
duaribu_dir =os.path.join(bahan_dir, 'duaribu/')
seribu_dir =os.path.join(bahan_dir, 'seribu/')

print("Jumlah Data Train Tiap Kelas")
print("Jumlah gambar uang 100.000 :", len(os.listdir(seratus_dir)))
print("Jumlah gambar uang 75.000 :", len(os.listdir(tujuhpuluhlima_dir)))
print("Jumlah gambar uang 50.000 :", len(os.listdir(limapuluh_dir)))
print("Jumlah gambar uang 20.000 :", len(os.listdir(duapuluh_dir)))
print("Jumlah gambar uang 10.000 :", len(os.listdir(sepuluh_dir)))
print("Jumlah gambar uang 5.000 :", len(os.listdir(limaribu_dir)))
print("Jumlah gambar uang 2.000 :", len(os.listdir(duaribu_dir)))
print("Jumlah gambar uang 1.000 :", len(os.listdir(seribu_dir)))
# Out:
# Jumlah Data Train Tiap Kelas
# Jumlah gambar uang 100.000 : 42
# Jumlah gambar uang 75.000 : 20
# Jumlah gambar uang 50.000 : 62
# Jumlah gambar uang 20.000 : 70
# Jumlah gambar uang 10.000 : 72
# Jumlah gambar uang 5.000 : 56
# Jumlah gambar uang 2.000 : 46
# Jumlah gambar uang 1.000 : 10

# %%
#direktori isi latih/training
train_seratus = os.path.join(train_dir, 'seratus/')
train_tujuhpuluhlima = os.path.join(train_dir, 'tujuhpuluhlima/')
train_limapuluh = os.path.join(train_dir, 'limapuluh/')
train_duapuluh = os.path.join(train_dir, 'duapuluh/')
train_sepuluh = os.path.join(train_dir, 'sepuluh/')
train_limaribu = os.path.join(train_dir, 'limaribu/')
train_duaribu = os.path.join(train_dir, 'duaribu/')
train_seribu = os.path.join(train_dir, 'seribu/')

#direktori isi validasi
validation_seratus = os.path.join(validation_dir, 'seratus/')
validation_tujuhpuluhlima = os.path.join(validation_dir, 'tujuhpuluhlima/')
validation_limapuluh = os.path.join(validation_dir, 'limapuluh/')
validation_duapuluh = os.path.join(validation_dir, 'duapuluh/')
validation_sepuluh = os.path.join(validation_dir, 'sepuluh/')
validation_limaribu = os.path.join(validation_dir, 'limaribu/')
validation_duaribu = os.path.join(validation_dir, 'duaribu/')
validation_seribu = os.path.join(validation_dir, 'seribu/')

# %%
import random
from shutil import copyfile

def train_val_split(source, train, val, train_ration):
  total_size = len(os.listdir(source))
  train_size = int(train_ratio * total_size)
  val_size = total_size - train_size

  randomized = random.sample(os.listdir(source), total_size)
  train_files = randomized[0:train_size]
  val_files = randomized[train_size:total_size]

  for i in train_files:
    i_file = source + i
    destination = train + i
    copyfile(i_file, destination)

  for i in val_files:
    i_file = source + i
    destination = val + i
    copyfile(i_file, destination)

#jumlah pembagian data training dan testing
train_ratio = 0.9

#pembagian training dan validasi

#training
source_00 = seratus_dir
train_00 = train_seratus
val_00 = validation_seratus
train_val_split(source_00, train_00, val_00, train_ratio)

source_01 = tujuhpuluhlima_dir
train_01 = train_tujuhpuluhlima
val_01 = validation_tujuhpuluhlima
train_val_split(source_01, train_01, val_01, train_ratio)

#validasi
source_02 = limapuluh_dir
train_02 = train_limapuluh
val_02 = validation_limapuluh
train_val_split(source_02, train_02, val_02, train_ratio)

source_03 = duapuluh_dir
train_03 = train_duapuluh
val_03 = validation_duapuluh
train_val_split(source_03, train_03, val_03, train_ratio)

source_04 = sepuluh_dir
train_04 = train_sepuluh
val_04 = validation_sepuluh
train_val_split(source_04, train_04, val_04, train_ratio)

source_05 = limaribu_dir
train_05 = train_limaribu
val_05 = validation_limaribu
train_val_split(source_05, train_05, val_05, train_ratio)

source_06 = duaribu_dir
train_06 = train_duaribu
val_06 = validation_duaribu
train_val_split(source_06, train_06, val_06, train_ratio)

source_07 = seribu_dir
train_07 = train_seribu
val_07 = validation_seribu
train_val_split(source_07, train_07, val_07, train_ratio)

# %%
print('Jumlah All seratus :', len(os.listdir(seratus_dir)))
print('Jumlah Train seratus :', len(os.listdir(train_seratus)))
print('Jumlah Val seratus :', len(os.listdir(validation_seratus)))
print('')
print('Jumlah All tujuh puluh lima :', len(os.listdir(tujuhpuluhlima_dir)))
print('Jumlah Train tujuh puluh lima :', len(os.listdir(train_tujuhpuluhlima)))
print('Jumlah Val tujuh puluh lima :', len(os.listdir(validation_tujuhpuluhlima)))
print('')
print('Jumlah All lima puluh :', len(os.listdir(limapuluh_dir)))
print('Jumlah Train lima puluh :', len(os.listdir(train_limapuluh)))
print('Jumlah Val lima puluh :', len(os.listdir(validation_limapuluh)))
print('')
print('Jumlah All dua puluh :', len(os.listdir(duapuluh_dir)))
print('Jumlah Train dua puluh :', len(os.listdir(train_duapuluh)))
print('Jumlah Val dua puluh :', len(os.listdir(validation_duapuluh)))
print('')
print('Jumlah All sepuluh :', len(os.listdir(sepuluh_dir)))
print('Jumlah Train sepuluh :', len(os.listdir(train_sepuluh)))
print('Jumlah Val sepuluh :', len(os.listdir(validation_sepuluh)))
print('')
print('Jumlah All lima ribu :', len(os.listdir(limaribu_dir)))
print('Jumlah Train lima ribu :', len(os.listdir(train_limaribu)))
print('Jumlah Val lima ribu :', len(os.listdir(validation_limaribu)))
print('')
print('Jumlah All dua ribu :', len(os.listdir(duaribu_dir)))
print('Jumlah Train dua ribu :', len(os.listdir(train_duaribu)))
print('Jumlah Val dua ribu :', len(os.listdir(validation_duaribu)))
print('')
print('Jumlah All seribu :', len(os.listdir(seribu_dir)))
print('Jumlah Train seribu :', len(os.listdir(train_seribu)))
print('Jumlah Val seribu :', len(os.listdir(validation_seribu)))
# Out:
# Jumlah All seratus : 42
# Jumlah Train seratus : 42
# Jumlah Val seratus : 24
#
# Jumlah All tujuh puluh lima : 20
# Jumlah Train tujuh puluh lima : 20
# Jumlah Val tujuh puluh lima : 8
#
# Jumlah All lima puluh : 62
# Jumlah Train lima puluh : 62
# Jumlah Val lima puluh : 36
#
# Jumlah All dua puluh : 70
# Jumlah Train dua puluh : 70
# Jumlah Val dua puluh : 28
#
# Jumlah All sepuluh : 72
# Jumlah Train sepuluh : 72
# Jumlah Val sepuluh : 31
#
# Jumlah All lima ribu : 56
# Jumlah Train lima ribu : 56
# Jumlah Val lima ribu : 26
#
# Jumlah All dua ribu : 46
# Jumlah Train dua ribu : 46
# Jumlah Val dua ribu : 20
#
# Jumlah All seribu : 10
# Jumlah Train seribu : 10
# Jumlah Val seribu : 5

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    horizontal_flip = True,
    shear_range = 0.3,
    fill_mode = 'nearest',
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.1
)

val_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    horizontal_flip = True,
    shear_range = 0.3,
    fill_mode = 'nearest',
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.1
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    batch_size = 10,
    class_mode = 'categorical'
)

val_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    batch_size = 10,
    class_mode = 'categorical'
)
# Out:
# Found 378 images belonging to 8 classes.
# Found 178 images belonging to 8 classes.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nAkurasi mencapai 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation = 'relu', input_shape = (150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dropout(0.3, seed = 112),
    tf.keras.layers.Dense(500, activation = 'relu'),
    tf.keras.layers.Dropout(0.5, seed = 112),
    tf.keras.layers.Dense(8, activation = 'sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 200)               3699400
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 500)               100500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_2 (Dense)             (None, 8)                 4008
#
# ...
# Total params: 3,827,492
# Trainable params: 3,827,492
# ...

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'Adam',
              metrics = ['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch = 30,
      epochs = 250,
      validation_data = val_generator,
      validation_steps = 1,
      verbose = 1,
      callbacks = [callbacks])
# Out:
# Epoch 1/250
# 30/30 [==============================] - 14s 479ms/step - loss: 1.0994 - accuracy: 0.5705 - val_loss: 1.0357 - val_accuracy: 0.6000
# Epoch 2/250
# 30/30 [==============================] - 12s 418ms/step - loss: 1.2544 - accuracy: 0.5336 - val_loss: 1.0755 - val_accuracy: 0.5000
# Epoch 3/250
# 30/30 [==============================] - 13s 428ms/step - loss: 1.1334 - accuracy: 0.6141 - val_loss: 0.7988 - val_accuracy: 0.6000
# Epoch 4/250
# 30/30 [==============================] - 12s 413ms/step - loss: 1.0512 - accuracy: 0.6275 - val_loss: 1.2458 - val_accuracy: 0.5000
# Epoch 5/250
# 30/30 [==============================] - 13s 442ms/step - loss: 1.2280 - accuracy: 0.5570 - val_loss: 1.1542 - val_accuracy: 0.6000
# Epoch 6/250
# 30/30 [==============================] - 13s 450ms/step - loss: 1.0647 - accuracy: 0.6174 - val_loss: 0.8514 - val_accuracy: 0.6000
# Epoch 7/250
# ...

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
plt.legend(loc = 'best')
plt.show()

# %%
import numpy as np
import keras.utils as image
from keras.preprocessing import image
from keras.utils import load_img, img_to_array
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  #prediksi image
  path = fn
  img = load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  image = np.vstack([x])
  classes = model.predict(image, batch_size = 100)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('Ini adalah gambar mata uang ', class_list[j])
      break
# Out:
#      <input type="file" id="files-20366502-4e95-4eb9-8477-e6e34fa8ad3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20366502-4e95-4eb9-8477-e6e34fa8ad3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
